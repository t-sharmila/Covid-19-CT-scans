# %%
from covid_final import Predictor

# %%
import argparse
from imutils import paths

# %%
model_file='/ebsvol/aicelerateData/internuser/Sharmila/simpletrain.h5'
ap = argparse.ArgumentParser()
ap.add_argument("-t", "--test", required=True,help="path to test images")
args = vars(ap.parse_args("--test /ebsvol/aicelerateData/internuser/Sharmila/test".split()))
imagePaths = list(paths.list_images(args["test"]))

# %%
Predictor(model_file,imagePaths)
# Out:
# Actual_output:covid-3
# Model_output: Covid_infected_CT
# Time:0.527254306973191
#
# Actual_output:covid
# Model_output: Covid_infected_CT
# Time:0.45640254000318237
#
# Actual_output:non_covid-2
# Model_output: Covid_infected_CT
# Time:0.4495369359792676
#
# Actual_output:covid-1
# Model_output: Covid_infected_CT
# Time:0.4474429730034899
#
# Actual_output:non_covid-3
# Model_output: Non_covid
# Time:0.5716371500166133
